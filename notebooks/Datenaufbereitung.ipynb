# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Zone1 = pd.read_csv("./data/out_1.csv", sep=";")
Zone2 = pd.read_csv("./data/out_2.csv", sep=";")

# %%
Zone1['Datum'] = pd.to_datetime(Zone1['Datum'], dayfirst=True)
Zone2['Date'] = pd.to_datetime(Zone2['Date'], dayfirst=True)

# %%
print(Zone1)
# Out:
#         Datum Uhrzeit  m [kg]  v [m/s]
# 0  2019-01-01   09:00     194      8.4
# 1  2019-01-01   21:00     224      8.8
# 2  2019-01-02   14:00    3104      9.2
# 3  2019-01-04   15:00     228      8.0
# 4  2019-01-05   23:00     755      7.0
# ..        ...     ...     ...      ...
# 63 2019-03-18   16:00     167      8.9
# 64 2019-03-22   18:00    2847      7.0
# 65 2019-03-26   00:00      44      8.9
# 66 2019-03-26   06:00      45      8.4
# 67 2019-03-27   16:00     312      5.8
#
# [68 rows x 4 columns]

# %%
print(Zone2)
# Out:
#          Date Uhrzeit  m [kg]  v [m/s]
# 0  2019-01-01   09:00      38     45.4
# 1  2019-01-03   06:00     187     41.6
# 2  2019-01-04   10:00      36     44.6
# 3  2019-01-07   14:00       6     41.2
# 4  2019-01-11   06:00      65     39.6
# 5  2019-01-11   16:00      58     33.2
# 6  2019-01-14   11:00     365     40.2
# 7  2019-01-16   02:00      22     46.5
# 8  2019-01-18   06:00     146     36.2
# 9  2019-01-19   17:00      29     38.3
# 10 2019-01-20   22:00      40     41.6
# 11 2019-01-21   11:00     304     36.7
# 12 2019-01-22   21:00      33     44.1
# 13 2019-01-29   07:00      50     40.0
# 14 2019-02-06   02:00      77     38.0
# 15 2019-02-10   20:00      76     39.2
# 16 2019-02-14   05:00     138     33.2
# 17 2019-02-15   11:00     152     24.9
# 18 2019-02-16   18:00     241     40.6
# 19 2019-02-25   14:00      97     30.0
# 20 2019-02-28   05:00      37     32.2
# 21 2019-02-28   12:00      64     34.3
# 22 2019-03-07   21:00      55     31.7
# 23 2019-03-10   16:00       0     32.3
# 24 2019-03-10   23:00      45     32.2
# 25 2019-03-11   18:00     406     44.1
# 26 2019-03-17   09:00      58     33.6
# 27 2019-03-20   10:00      16     42.1
# 28 2019-03-21   13:00     211     29.0
# 29 2019-03-24   16:00       3     42.3
# 30 2019-03-25   14:00      63     43.2
# 31 2019-03-28   01:00      58     37.2

# %% [markdown]
# # Häufigkeitsverteilung der Geschwindigkeit

# %% [markdown]
# ## Zone1

# %%
Zone1.hist(column='v [m/s]', bins=20, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'v [m/s]'}>]], dtype=object)

# %% [markdown]
# ## Zone2

# %%
Zone2.hist(column='v [m/s]', bins=20, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'v [m/s]'}>]], dtype=object)

# %% [markdown]
# # Häufigkeitsverteilung der Masse

# %% [markdown]
# ## Zone1

# %%
Zone1.hist(column='m [kg]', bins=20, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'m [kg]'}>]], dtype=object)

# %% [markdown]
# ## Zone2

# %%
Zone2.hist(column='m [kg]', bins=20, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'m [kg]'}>]], dtype=object)

# %% [markdown]
# # Geschwindigkeit in Abhängigkeit von der Masse

# %% [markdown]
# ## Zone1

# %%
Zone1.plot.scatter(x = 'm [kg]', y = 'v [m/s]', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='m [kg]', ylabel='v [m/s]'>

# %% [markdown]
# ## Zone2

# %%
Zone2.plot.scatter(x = 'm [kg]', y = 'v [m/s]', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='m [kg]', ylabel='v [m/s]'>

# %% [markdown]
# # Steinschläge pro Tag (Tagen an denen nichts passiert ist einfügen)

# %% [markdown]
# ## Zone1

# %%
Zone1['Month'] = Zone1['Datum'].apply(lambda x: "%d" % (x.month))
Zone1
Zone1.groupby('Month').size()
# Out:
# Month
# 1    23
# 2    24
# 3    21
# dtype: int64

# %%
Zone1.value_counts('Datum').sort_index().plot(kind='bar',figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Datum'>

# %% [markdown]
# ## Zone2

# %%
Zone2['Month'] = Zone2['Date'].apply(lambda x: "%d" % (x.month))
Zone2
Zone2.groupby('Month').size()
# Out:
# Month
# 1    14
# 2     8
# 3    10
# dtype: int64

# %%
Zone2.value_counts('Date').sort_index().plot(kind='bar',figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Steinschläge pro Stunde

# %% [markdown]
# ## Zone1

# %%
Uhrzeit1 = Zone1.sort_values(by=['Uhrzeit'])
Uhrzeit1.plot.scatter(x = 'Uhrzeit', y = 'm [kg]', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Uhrzeit', ylabel='m [kg]'>

# %%
Zone1.value_counts('Uhrzeit').sort_index().plot(kind='bar',figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Uhrzeit'>

# %% [markdown]
# ## Zone2

# %%
Uhrzeit2 = Zone2.sort_values(by=['Uhrzeit'])
Uhrzeit2.plot.scatter(x = 'Uhrzeit', y = 'm [kg]', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Uhrzeit', ylabel='m [kg]'>

# %%
Zone2.value_counts('Uhrzeit').sort_index().plot(kind='bar',figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Uhrzeit'>
